# %%
import sys

# %%
sys.executable
# Out:
# 'C:\\Users\\zcole\\my_projects\\hsco_bro_20\\env-hsco\\python.exe'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
#import seaborn as sns

# %%
df19 = pd.read_excel("C:/Users/zcole/my_projects/hsco_bro_20/inputs/pir_export_2019/pir_export_2019.xlsx", 
                     sheet_name="Section C", 
                     header=1, 
                     skipfooter=1)

df18 = pd.read_excel("C:/Users/zcole/my_projects/hsco_bro_20/inputs/pir_export_2018/pir_export_2018.xlsx", 
                     sheet_name="Section C", 
                     header=1, 
                     skipfooter=1)

df17 = pd.read_excel("C:/Users/zcole/my_projects/hsco_bro_20/inputs/pir_export_2017/pir_export_2017.xlsx", 
                     sheet_name="Section C", 
                     header=1, 
                     skipfooter=1)

df16 = pd.read_excel("C:/Users/zcole/my_projects/hsco_bro_20/inputs/pir_export_2016/pir_export_2016.xlsx", 
                     sheet_name="Section C", 
                     header=1, 
                     skipfooter=1)

df15 = pd.read_excel("C:/Users/zcole/my_projects/hsco_bro_20/inputs/pir_export_2015/pir_export_2015.xlsx", 
                     sheet_name="Section C", 
                     header=1, 
                     skipfooter=1)

# %%
df19['yr'] = "2019"
df18['yr'] = "2018"
df17['yr'] = "2017"
df16['yr'] = "2016"
df15['yr'] = "2015"

# %%
frames = [df19,df18,df17,df16,df15]

df = pd.concat(frames, join='outer', sort=False)

df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16326 entries, 0 to 2932
# Columns: 308 entries, Region to C.59.a
# dtypes: float64(246), int64(1), object(61)
# memory usage: 38.5+ MB
#      Region State Grant Number  Program Number Type  \
# 0  Region 1    CT   01CH010234               0   HS
# 1  Region 1    CT   01CH010234             200  EHS
# 2  Region 1    CT   01CH010313               0   HS
# 3  Region 1    CT   01CH010313             200  EHS
# 4  Region 1    CT   01CH010398               0   HS
#
#                                              Grantee  \
# 0                                          Edadvance
# 1                                          Edadvance
# 2        Connecticut Institute for Communities, Inc.
# 3        Connecticut Institute for Communities, Inc.
# 4  Eastern Connecticut Regional Educational Servi...
#
#                                          Program        City  ZIP Code  \
# 0                                      EdAdvance  Litchfield    6759.0
# 1                                      EdAdvance  Litchfield    6759.0
# 2        Head Start of Northern Fairfield County     Danbury    6810.0
# 3  Early Head Start of Northern Fairfield County     Danbury    6810.0
# 4                            EASTCONN Head Start     Hampton    6247.0
#
#     ZIP 4  ...  C.48.a  C.49  C.50  C.51  C.52  C.54.a  C.56.a  C.56.b  \
# 0  2404.0  ...     NaN   NaN   NaN   NaN   NaN     NaN     NaN     NaN
# 1  2404.0  ...     NaN   NaN   NaN   NaN   NaN     NaN     NaN     NaN
# 2  7834.0  ...     NaN   NaN   NaN   NaN   NaN     NaN     NaN     NaN
# 3  7834.0  ...     NaN   NaN   NaN   NaN   NaN     NaN     NaN     NaN
# 4  1320.0  ...     NaN   NaN   NaN   NaN   NaN     NaN     NaN     NaN
#
#    C.57.a  C.59.a
# 0     NaN     NaN
# 1     NaN     NaN
# 2     NaN     NaN
# 3     NaN     NaN
# 4     NaN     NaN
#
# [5 rows x 308 columns]

# %%
ok = df[df.State == "OK"]

ok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 300 entries, 2101 to 2919
# Columns: 308 entries, Region to C.59.a
# dtypes: float64(246), int64(1), object(61)
# memory usage: 724.2+ KB

# %%
###

#c5-1, c5-2
#Children continuous accessible health care (at enrollment), children continuous accessible health care (end of year)

#hs = ok[(ok['Program Number'] < 200)].groupby(['yr'], as_index=False)[['C.5-1','C.5-2']].agg("sum")
#ehs = ok[(ok['Program Number'] == 200)].groupby(['yr'], as_index=False)[['C.5-1','C.5-2']].agg("sum")
#cahok = ok.groupby(['yr'], as_index=False)[['C.5-1','C.5-2']].agg("sum")

###

#c17-1, c17-2
#Children continuous accessible dental care (at enrollment), children continuous accessible health care (end of year)

hs = ok[(ok['Program Number'] < 200)].groupby(['yr'], as_index=False)[['C.17-1','C.17-2']].agg("sum")
ehs = ok[(ok['Program Number'] == 200)].groupby(['yr'], as_index=False)[['C.17-1','C.17-2']].agg("sum")
cadok = ok.groupby(['yr'], as_index=False)[['C.17-1','C.17-2']].agg("sum")

###

# %%
hs.info()
hs
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   yr      5 non-null      object
#  1   C.17-1  5 non-null      float64
#  2   C.17-2  5 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 160.0+ bytes
#      yr   C.17-1   C.17-2
# 0  2015  13346.0  15398.0
# 1  2016  13163.0  15372.0
# 2  2017  13107.0  15172.0
# 3  2018  12238.0  14268.0
# 4  2019  12410.0  13915.0

# %%
ehs.info()
ehs
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   yr      5 non-null      object
#  1   C.17-1  5 non-null      float64
#  2   C.17-2  5 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 160.0+ bytes
#      yr  C.17-1  C.17-2
# 0  2015  1705.0  2087.0
# 1  2016  2024.0  2356.0
# 2  2017  2374.0  2888.0
# 3  2018  2819.0  3377.0
# 4  2019  3293.0  3591.0

# %%
cadok.info()
cadok
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   yr      5 non-null      object
#  1   C.17-1  5 non-null      float64
#  2   C.17-2  5 non-null      float64
# dtypes: float64(2), object(1)
# memory usage: 160.0+ bytes
#      yr   C.17-1   C.17-2
# 0  2015  15051.0  17485.0
# 1  2016  15187.0  17728.0
# 2  2017  15481.0  18060.0
# 3  2018  15057.0  17645.0
# 4  2019  15703.0  17506.0

# %%
plt.get_backend()
# Out:
# 'module://ipykernel.pylab.backend_inline'

# %%
plt.rcdefaults()

# %%
plt.style.use('seaborn-whitegrid')

#plt.rcParams.update({"figure.autolayout": True})
plt.rcParams["figure.autolayout"] = "True"

plt.rcParams["axes.spines.top"] = "False"
plt.rcParams["axes.spines.bottom"] = "False"
plt.rcParams["axes.spines.left"] = "False"
plt.rcParams["axes.spines.right"] = "False"

#plt.rcParams["axes.grid"] = "True"
#plt.rcParams["axes.axisbelow"] = "True"
plt.rcParams["grid.linewidth"] = 0.75

plt.rcParams["figure.figsize"] = [12.8,6.8]

plt.rcParams["legend.borderpad"] = 0.2
plt.rcParams["legend.borderaxespad"] = 0.0
plt.rcParams["legend.labelspacing"] = 0
plt.rcParams["legend.handlelength"] = 0.8
plt.rcParams["legend.handletextpad"] = 0.125
#plt.rcParams["legend.loc"] = "upper right"

labels = cadok.yr
a = cadok['C.17-1']
b = cadok['C.17-2']
#c = hs['C.19.a.1']

x = np.arange(len(labels))
width = 0.25

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2.0, a, width, color="#b92053", label="At Enrollment")
rects2 = ax.bar(x + width/2.0, b, width, color="#005282", label="End of Year")
#rects3 = ax.bar(x + 0.75/2.0, c, width, color="#000000", label="Diagnosed as Needing Treatment")

#ax.set_ylim(0, 17000)
ax.set_yticks([0,5000,10000,15000,20000])
ax.set_ylabel("Children (EHS & HS)", size=24)
ax.set_title("Children with a Dental Home", color="#b92053", weight="bold", size=36)
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.tick_params(axis="both", labelsize=26)
ax.legend(fontsize=24)

def autolabel(rects):
    for rect in rects:
        height = rect.get_height()
        ax.annotate("{}".format(height), 
                    xy=(rect.get_x() + rect.get_width() / 2, height), 
                    xytext=(0, 3), 
                    textcoords="offset points", 
                    ha="center", va="bottom")
        
    
#autolabel(rects1)
#autolabel(rects2)

plt.savefig("C:/Users/zcole/my_projects/hsco_bro_20/outputs/cad-ok1.svg",transparent=True)

plt.show()
